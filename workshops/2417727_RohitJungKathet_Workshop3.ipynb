# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns # type: ignore
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
titanic_df = pd.read_csv('../datasets/Titanic-Dataset.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
fare = titanic_df.sort_values(by='Fare')
fare[['Fare']].head()
# Out:
#      Fare
# 271   0.0
# 597   0.0
# 302   0.0
# 633   0.0
# 277   0.0

# %%
class_age = titanic_df.sort_values(['Pclass', 'Age'])
class_age[['Pclass', 'Age']].head()
# Out:
#      Pclass    Age
# 305       1   0.92
# 297       1   2.00
# 445       1   4.00
# 802       1  11.00
# 435       1  14.00

# %%
survived_gender = titanic_df.sort_values(['Survived', 'Sex'])
survived_gender[['Survived', 'Sex']].head()
# Out:
#     Survived     Sex
# 14         0  female
# 18         0  female
# 24         0  female
# 38         0  female
# 40         0  female

# %%
fare_gt_100 = titanic_df.loc[titanic_df['Fare'] > 100]
fare_gt_100.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 337          338         1       1
# 319          320         1       1
# 779          780         1       1
# 802          803         1       1
# 557          558         0       1
# 269          270         1       1
# 377          378         0       1
# 435          436         1       1
# 332          333         0       1
# 581          582         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 337                    Burns, Miss. Elizabeth Margaret  female  41.0      0
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 802                Carter, Master. William Thornton II    male  11.0      1
# 557                                Robbins, Mr. Victor    male   NaN      0
# 269                             Bissette, Miss. Amelia  female  35.0      0
# ...

# %%
female_under_18 = titanic_df.loc[(titanic_df['Sex'] == 'female') & (titanic_df['Age'] < 18)]
female_under_18.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 58            59         1       2         West, Miss. Constance Mirium
# 297          298         0       1         Allison, Miss. Helen Loraine
# 634          635         0       3                   Skoog, Miss. Mabel
# 720          721         1       2    Harper, Miss. Annie Jessie "Nina"
# 875          876         1       3     Najib, Miss. Adele Kiamie "Jane"
# 184          185         1       3  Kink-Heilmann, Miss. Luise Gretchen
# 39            40         1       3          Nicola-Yarred, Miss. Jamila
# 24            25         0       3        Palsson, Miss. Torborg Danira
# 419          420         0       3            Van Impe, Miss. Catharina
# 374          375         0       3           Palsson, Miss. Stina Viola
#
#         Sex   Age  SibSp  Parch      Ticket      Fare    Cabin Embarked
# 58   female   5.0      1      2  C.A. 34651   27.7500      NaN        S
# ...

# %%
embarked_c_or_s = titanic_df.loc[titanic_df['Embarked'].isin(['C', 'S'])]
embarked_c_or_s.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 538          539         0       3
# 394          395         1       3
# 41            42         0       2
# 209          210         1       1
# 630          631         1       1
# 611          612         0       3
# 133          134         1       2
# 170          171         0       1
# 688          689         0       3
# 639          640         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 538                           Risien, Mr. Samuel Beard    male   NaN      0
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 209                                   Blank, Mr. Henry    male  40.0      0
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 611                              Jardin, Mr. Jose Neto    male   NaN      0
# ...

# %%
first_second_class = titanic_df.loc[titanic_df['Pclass'].isin([1, 2])]
first_second_class.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 626          627         0       2          Kirkland, Rev. Charles Leonard
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
# 694          695         0       1                         Weir, Col. John
# 237          238         1       2        Collyer, Miss. Marjorie "Lottie"
# 387          388         1       2                        Buss, Miss. Kate
# 435          436         1       1               Carter, Miss. Lucile Polk
# 883          884         0       2           Banfield, Mr. Frederick James
# 659          660         0       1              Newell, Mr. Arthur Webster
# 714          715         0       2                   Greenberg, Mr. Samuel
# 673          674         1       2                   Wilhelms, Mr. Charles
#
#         Sex   Age  SibSp  Parch            Ticket     Fare    Cabin Embarked
# ...

# %%
titanic_df['fare_per_year'] = titanic_df['Fare'] / titanic_df['Age']

# %%
high_fare_age = titanic_df.loc[titanic_df['fare_per_year'] > 5]

# %%
high_fare_age_srt = high_fare_age.sort_values('fare_per_year', ascending=False)

# %%
result = high_fare_age_srt[['Name', 'fare_per_year']]
result
# Out:
#                                        Name  fare_per_year
# 305          Allison, Master. Hudson Trevor     164.728261
# 297            Allison, Miss. Helen Loraine      75.775000
# 386         Goodwin, Master. Sidney Leonard      46.900000
# 164            Panula, Master. Eino Viljami      39.687500
# 183               Becker, Master. Richard F      39.000000
# ..                                      ...            ...
# 318                Wick, Miss. Mary Natalie       5.318281
# 348  Coutts, Master. William Loch "William"       5.300000
# 205              Strom, Miss. Telma Matilda       5.231250
# 813      Andersson, Miss. Ebba Iris Alfrida       5.212500
# 480          Goodwin, Master. Harold Victor       5.211111
#
# [68 rows x 2 columns]

# %%
titanic_df['fare_per_class'] = titanic_df['Fare'] / titanic_df['Pclass']

# %%
adult_males = titanic_df.loc[(titanic_df["Sex"] == "male") & (titanic_df["Age"] >= 18)]

# %%
adult_males_srt = adult_males.sort_values('fare_per_class', ascending=False)

# %%
adult_males_srt[["Name", "Age", "fare_per_class"]]
# Out:
#                                    Name   Age  fare_per_class
# 737              Lesurer, Mr. Gustave J  35.0        512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0        512.3292
# 27       Fortune, Mr. Charles Alexander  19.0        263.0000
# 438                   Fortune, Mr. Mark  64.0        263.0000
# 118            Baxter, Mr. Quigg Edmond  24.0        247.5208
# ..                                  ...   ...             ...
# 271        Tornquist, Mr. William Henry  25.0          0.0000
# 179                 Leonard, Mr. Lionel  36.0          0.0000
# 302     Johnson, Mr. William Cahoone Jr  19.0          0.0000
# 822     Reuchlin, Jonkheer. John George  38.0          0.0000
# 806              Andrews, Mr. Thomas Jr  39.0          0.0000
#
# [395 rows x 3 columns]

# %%
total_fare = titanic_df['Fare'].sum()
total_fare
# Out:
# 28693.9493

# %%
first_class = titanic_df.loc[titanic_df['Pclass'] == 1]
first_class_fare = first_class['Fare'].sum()
first_class_fare
# Out:
# 18177.4125

# %%
second_class = titanic_df.loc[titanic_df['Pclass'] == 2]
second_class_fare = second_class['Fare'].sum()
second_class_fare
# Out:
# 3801.8417

# %%
third_class = titanic_df.loc[titanic_df['Pclass'] == 3]
third_class_fare = third_class['Fare'].sum()
third_class_fare
# Out:
# 6714.6951

# %%
fare_list = [first_class_fare, second_class_fare, third_class_fare]
fare_list
# Out:
# [18177.4125, 3801.8417, 6714.6951]

# %%
#proportion of fare revenue by class
proportions = np.array(fare_list) / total_fare
proportions
# Out:
# array([0.63349288, 0.13249629, 0.23401084])

# %%
titanic_df.dropna(subset=['Age'], inplace= True)

# titanic_df['Age']= titanic_df['Age'].dropna()
titanic_df['Age'].isnull().sum()
titanic_df['Age'].sample(10)
# Out:
# 129    45.0
# 206    32.0
# 365    30.0
# 25     38.0
# 224    38.0
# 716    38.0
# 14     14.0
# 838    32.0
# 577    39.0
# 417    18.0
# Name: Age, dtype: float64

# %%
titanic_df['age_group'] = pd.cut(titanic_df['Age'], bins=[0, 17, 64, float('inf')], labels=['Child', 'Adult', 'Senior'])

# %%
total_passengers = titanic_df['PassengerId'].count()
total_passengers
# Out:
# 714

# %%
age_group_values = titanic_df['age_group'].value_counts()
age_group_values
# Out:
# age_group
# Adult     590
# Child     113
# Senior     11
# Name: count, dtype: int64

# %%
prop = age_group_values / total_passengers
prop
# Out:
# age_group
# Adult     0.826331
# Child     0.158263
# Senior    0.015406
# Name: count, dtype: float64

# %%
prop_percentage = prop * 100
prop_percentage
# Out:
# age_group
# Adult     82.633053
# Child     15.826331
# Senior     1.540616
# Name: count, dtype: float64
